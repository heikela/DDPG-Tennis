# %%
import os
import torch
import re
import pandas

# %%
all_files = os.listdir()
end = 10000
retired_models = [file for file in all_files if 'retire' in file]
models_at_end = [file for file in all_files if str(end) in file and not 'retire' in file]
len(retired_models + models_at_end)
# Out:
# 227

# %%
population_size = 16

# %%
histories = [None for i in range(population_size)]

# %%
def get_retire_episode(filename):
    pattern = re.compile(r".*?episode_(\d*)\.")
    return int(pattern.match(filename).group(1))

# %%
get_retire_episode(retired_models[0])
# Out:
# 10000

# %%
models_to_process = sorted(retired_models, key = get_retire_episode) + models_at_end
models_to_process
# Out:
# ['retire_agent-6_episode_200.pth',
#  'retire_agent-0_episode_400.pth',
#  'retire_agent-15_episode_400.pth',
#  'retire_agent-1_episode_400.pth',
#  'retire_agent-5_episode_400.pth',
#  'retire_agent-11_episode_600.pth',
#  'retire_agent-14_episode_600.pth',
#  'retire_agent-13_episode_800.pth',
#  'retire_agent-2_episode_800.pth',
#  'retire_agent-3_episode_800.pth',
#  'retire_agent-12_episode_1000.pth',
#  'retire_agent-6_episode_1000.pth',
#  'retire_agent-11_episode_1200.pth',
#  'retire_agent-11_episode_1400.pth',
#  'retire_agent-2_episode_1400.pth',
#  'retire_agent-5_episode_1400.pth',
#  'retire_agent-11_episode_1600.pth',
#  'retire_agent-12_episode_1600.pth',
#  'retire_agent-5_episode_1600.pth',
#  'retire_agent-10_episode_1800.pth',
#  'retire_agent-13_episode_1800.pth',
#  'retire_agent-14_episode_1800.pth',
#  'retire_agent-15_episode_1800.pth',
#  'retire_agent-6_episode_1800.pth',
#  'retire_agent-10_episode_2000.pth',
#  'retire_agent-11_episode_2000.pth',
#  'retire_agent-13_episode_2000.pth',
#  'retire_agent-4_episode_2000.pth',
#  'retire_agent-9_episode_2000.pth',
#  'retire_agent-11_episode_2200.pth',
#  'retire_agent-12_episode_2200.pth',
#  'retire_agent-1_episode_2200.pth',
#  'retire_agent-7_episode_2200.pth',
#  'retire_agent-8_episode_2200.pth',
#  'retire_agent-0_episode_2400.pth',
#  'retire_agent-11_episode_2400.pth',
#  'retire_agent-12_episode_2400.pth',
#  'retire_agent-14_episode_2400.pth',
#  'retire_agent-1_episode_2400.pth',
#  'retire_agent-6_episode_2400.pth',
#  'retire_agent-0_episode_2600.pth',
#  'retire_agent-11_episode_2600.pth',
#  'retire_agent-13_episode_2600.pth',
#  'retire_agent-15_episode_2600.pth',
#  'retire_agent-2_episode_2600.pth',
#  'retire_agent-5_episode_2600.pth',
#  'retire_agent-6_episode_2600.pth',
#  'retire_agent-7_episode_2600.pth',
#  'retire_agent-10_episode_2800.pth',
#  'retire_agent-12_episode_2800.pth',
#  'retire_agent-14_episode_2800.pth',
#  'retire_agent-4_episode_2800.pth',
#  'retire_agent-5_episode_2800.pth',
#  'retire_agent-6_episode_2800.pth',
#  'retire_agent-8_episode_2800.pth',
#  'retire_agent-9_episode_2800.pth',
#  'retire_agent-10_episode_3000.pth',
#  'retire_agent-12_episode_3000.pth',
#  'retire_agent-13_episode_3000.pth',
#  'retire_agent-14_episode_3000.pth',
#  'retire_agent-4_episode_3000.pth',
#  'retire_agent-5_episode_3000.pth',
#  'retire_agent-6_episode_3000.pth',
#  'retire_agent-7_episode_3000.pth',
#  'retire_agent-10_episode_3200.pth',
#  'retire_agent-14_episode_3200.pth',
#  'retire_agent-2_episode_3200.pth',
#  'retire_agent-7_episode_3200.pth',
#  'retire_agent-9_episode_3200.pth',
#  'retire_agent-10_episode_3400.pth',
#  'retire_agent-12_episode_3400.pth',
#  'retire_agent-3_episode_3400.pth',
#  'retire_agent-4_episode_3400.pth',
#  'retire_agent-5_episode_3400.pth',
#  'retire_agent-6_episode_3400.pth',
#  'retire_agent-7_episode_3400.pth',
#  'retire_agent-10_episode_3600.pth',
#  'retire_agent-14_episode_3600.pth',
#  'retire_agent-8_episode_3600.pth',
#  'retire_agent-9_episode_3600.pth',
#  'retire_agent-10_episode_3800.pth',
#  'retire_agent-13_episode_3800.pth',
#  'retire_agent-15_episode_3800.pth',
#  'retire_agent-3_episode_3800.pth',
#  'retire_agent-8_episode_3800.pth',
#  'retire_agent-0_episode_4000.pth',
#  'retire_agent-10_episode_4000.pth',
#  'retire_agent-12_episode_4000.pth',
#  'retire_agent-15_episode_4000.pth',
#  'retire_agent-7_episode_4000.pth',
#  'retire_agent-10_episode_4200.pth',
#  'retire_agent-11_episode_4200.pth',
#  'retire_agent-14_episode_4200.pth',
#  'retire_agent-2_episode_4200.pth',
#  'retire_agent-8_episode_4200.pth',
#  'retire_agent-11_episode_4400.pth',
#  'retire_agent-15_episode_4400.pth',
#  'retire_agent-4_episode_4400.pth',
#  'retire_agent-6_episode_4600.pth',
#  'retire_agent-8_episode_4600.pth',
#  'retire_agent-11_episode_4800.pth',
#  'retire_agent-13_episode_4800.pth',
#  'retire_agent-15_episode_4800.pth',
#  'retire_agent-3_episode_4800.pth',
#  'retire_agent-4_episode_4800.pth',
#  'retire_agent-9_episode_4800.pth',
#  'retire_agent-0_episode_5000.pth',
#  'retire_agent-10_episode_5000.pth',
#  'retire_agent-8_episode_5000.pth',
#  'retire_agent-15_episode_5200.pth',
#  'retire_agent-6_episode_5200.pth',
#  'retire_agent-12_episode_5400.pth',
#  'retire_agent-13_episode_5400.pth',
#  'retire_agent-15_episode_5400.pth',
#  'retire_agent-2_episode_5400.pth',
#  'retire_agent-3_episode_5400.pth',
#  'retire_agent-6_episode_5400.pth',
#  'retire_agent-9_episode_5400.pth',
#  'retire_agent-0_episode_5600.pth',
#  'retire_agent-11_episode_5600.pth',
#  'retire_agent-5_episode_5600.pth',
#  'retire_agent-7_episode_5600.pth',
#  'retire_agent-9_episode_5600.pth',
#  'retire_agent-14_episode_5800.pth',
#  'retire_agent-1_episode_5800.pth',
#  'retire_agent-2_episode_5800.pth',
#  'retire_agent-6_episode_5800.pth',
#  'retire_agent-9_episode_5800.pth',
#  'retire_agent-0_episode_6000.pth',
#  'retire_agent-11_episode_6000.pth',
#  'retire_agent-12_episode_6000.pth',
#  'retire_agent-14_episode_6000.pth',
#  'retire_agent-15_episode_6000.pth',
#  'retire_agent-4_episode_6000.pth',
#  'retire_agent-7_episode_6000.pth',
#  'retire_agent-0_episode_6200.pth',
#  'retire_agent-12_episode_6200.pth',
#  'retire_agent-2_episode_6200.pth',
#  'retire_agent-4_episode_6200.pth',
#  'retire_agent-5_episode_6200.pth',
#  'retire_agent-6_episode_6200.pth',
#  'retire_agent-9_episode_6200.pth',
#  'retire_agent-14_episode_6400.pth',
#  'retire_agent-15_episode_6400.pth',
#  'retire_agent-1_episode_6400.pth',
#  'retire_agent-7_episode_6400.pth',
#  'retire_agent-8_episode_6400.pth',
#  'retire_agent-9_episode_6400.pth',
#  'retire_agent-0_episode_6600.pth',
#  'retire_agent-10_episode_6600.pth',
#  'retire_agent-13_episode_6600.pth',
#  'retire_agent-1_episode_6600.pth',
#  'retire_agent-6_episode_6600.pth',
#  'retire_agent-9_episode_6600.pth',
#  'retire_agent-14_episode_6800.pth',
#  'retire_agent-15_episode_6800.pth',
#  'retire_agent-2_episode_6800.pth',
#  'retire_agent-5_episode_6800.pth',
#  'retire_agent-6_episode_6800.pth',
#  'retire_agent-11_episode_7000.pth',
#  'retire_agent-12_episode_7000.pth',
#  'retire_agent-1_episode_7000.pth',
#  'retire_agent-2_episode_7000.pth',
#  'retire_agent-3_episode_7000.pth',
#  'retire_agent-4_episode_7000.pth',
#  'retire_agent-5_episode_7000.pth',
#  'retire_agent-6_episode_7000.pth',
#  'retire_agent-7_episode_7000.pth',
#  'retire_agent-8_episode_7000.pth',
#  'retire_agent-0_episode_7200.pth',
#  'retire_agent-10_episode_7200.pth',
#  'retire_agent-11_episode_7200.pth',
#  'retire_agent-14_episode_7200.pth',
#  'retire_agent-15_episode_7200.pth',
#  'retire_agent-1_episode_7200.pth',
#  'retire_agent-2_episode_7200.pth',
#  'retire_agent-3_episode_7200.pth',
#  'retire_agent-6_episode_7200.pth',
#  'retire_agent-0_episode_7400.pth',
#  'retire_agent-10_episode_7400.pth',
#  'retire_agent-11_episode_7400.pth',
#  'retire_agent-9_episode_7400.pth',
#  'retire_agent-14_episode_7600.pth',
#  'retire_agent-15_episode_7600.pth',
#  'retire_agent-12_episode_7800.pth',
#  'retire_agent-14_episode_7800.pth',
#  'retire_agent-2_episode_7800.pth',
#  'retire_agent-6_episode_7800.pth',
#  'retire_agent-8_episode_7800.pth',
#  'retire_agent-1_episode_8000.pth',
#  'retire_agent-3_episode_8000.pth',
#  'retire_agent-7_episode_8000.pth',
#  'retire_agent-9_episode_8000.pth',
#  'retire_agent-13_episode_8400.pth',
#  'retire_agent-0_episode_8600.pth',
#  'retire_agent-9_episode_8600.pth',
#  'retire_agent-2_episode_9000.pth',
#  'retire_agent-3_episode_9000.pth',
#  'retire_agent-5_episode_9000.pth',
#  'retire_agent-9_episode_9000.pth',
#  'retire_agent-15_episode_9200.pth',
#  'retire_agent-4_episode_9200.pth',
#  'retire_agent-7_episode_9200.pth',
#  'retire_agent-1_episode_9600.pth',
#  'retire_agent-2_episode_9600.pth',
#  'retire_agent-13_episode_9800.pth',
#  'retire_agent-15_episode_9800.pth',
#  'retire_agent-8_episode_9800.pth',
#  'retire_agent-0_episode_10000.pth',
#  'retire_agent-13_episode_10000.pth',
#  'retire_agent-2_episode_10000.pth',
#  'agent-0_episode_10000.pth',
#  'agent-10_episode_10000.pth',
#  'agent-11_episode_10000.pth',
#  'agent-12_episode_10000.pth',
#  'agent-13_episode_10000.pth',
#  'agent-14_episode_10000.pth',
#  'agent-15_episode_10000.pth',
#  'agent-1_episode_10000.pth',
#  'agent-2_episode_10000.pth',
#  'agent-3_episode_10000.pth',
#  'agent-4_episode_10000.pth',
#  'agent-5_episode_10000.pth',
#  'agent-6_episode_10000.pth',
#  'agent-7_episode_10000.pth',
#  'agent-8_episode_10000.pth',
#  'agent-9_episode_10000.pth']

# %%
def load_history(filename):
    return torch.load(filename)['history']

# %%
load_history(models_to_process[0])
# Out:
#    episode  return  actor_lr  critic_lr     tau  gamma
# 0        1    0.00     0.001     0.0003  0.0003   0.99
# 0        2    0.00     0.001     0.0003  0.0003   0.99
# 0        3    0.00     0.001     0.0003  0.0003   0.99
# 0        4   -0.01     0.001     0.0003  0.0003   0.99
# 0        5    0.00     0.001     0.0003  0.0003   0.99
# 0        6   -0.01     0.001     0.0003  0.0003   0.99
# 0        7   -0.01     0.001     0.0003  0.0003   0.99
# 0        8    0.00     0.001     0.0003  0.0003   0.99
# 0        9   -0.01     0.001     0.0003  0.0003   0.99
# 0       10    0.00     0.001     0.0003  0.0003   0.99
# 0       11   -0.01     0.001     0.0003  0.0003   0.99
# 0       12   -0.01     0.001     0.0003  0.0003   0.99
# 0       13    0.00     0.001     0.0003  0.0003   0.99
# 0       14    0.00     0.001     0.0003  0.0003   0.99
# 0       15    0.00     0.001     0.0003  0.0003   0.99
# 0       16    0.00     0.001     0.0003  0.0003   0.99
# 0       17   -0.01     0.001     0.0003  0.0003   0.99
# 0       18    0.00     0.001     0.0003  0.0003   0.99
# 0       19    0.00     0.001     0.0003  0.0003   0.99
# 0       20    0.00     0.001     0.0003  0.0003   0.99
# 0       21   -0.01     0.001     0.0003  0.0003   0.99
# 0       22    0.00     0.001     0.0003  0.0003   0.99
# 0       23    0.00     0.001     0.0003  0.0003   0.99
# 0       24   -0.01     0.001     0.0003  0.0003   0.99
# 0       25    0.00     0.001     0.0003  0.0003   0.99
# 0       26   -0.01     0.001     0.0003  0.0003   0.99
# 0       27   -0.01     0.001     0.0003  0.0003   0.99
# 0       28   -0.01     0.001     0.0003  0.0003   0.99
# 0       29    0.00     0.001     0.0003  0.0003   0.99
# 0       30    0.00     0.001     0.0003  0.0003   0.99
# ..     ...     ...       ...        ...     ...    ...
# 0      171   -0.01     0.001     0.0003  0.0003   0.99
# 0      172    0.00     0.001     0.0003  0.0003   0.99
# 0      173   -0.01     0.001     0.0003  0.0003   0.99
# 0      174    0.00     0.001     0.0003  0.0003   0.99
# 0      175   -0.01     0.001     0.0003  0.0003   0.99
# 0      176   -0.01     0.001     0.0003  0.0003   0.99
# 0      177   -0.01     0.001     0.0003  0.0003   0.99
# 0      178   -0.01     0.001     0.0003  0.0003   0.99
# 0      179    0.00     0.001     0.0003  0.0003   0.99
# 0      180    0.00     0.001     0.0003  0.0003   0.99
# 0      181    0.00     0.001     0.0003  0.0003   0.99
# 0      182   -0.01     0.001     0.0003  0.0003   0.99
# 0      183   -0.01     0.001     0.0003  0.0003   0.99
# 0      184   -0.01     0.001     0.0003  0.0003   0.99
# 0      185    0.00     0.001     0.0003  0.0003   0.99
# 0      186   -0.01     0.001     0.0003  0.0003   0.99
# 0      187    0.00     0.001     0.0003  0.0003   0.99
# 0      188   -0.01     0.001     0.0003  0.0003   0.99
# 0      189    0.00     0.001     0.0003  0.0003   0.99
# 0      190   -0.01     0.001     0.0003  0.0003   0.99
# 0      191   -0.01     0.001     0.0003  0.0003   0.99
# 0      192    0.00     0.001     0.0003  0.0003   0.99
# 0      193   -0.01     0.001     0.0003  0.0003   0.99
# 0      194   -0.01     0.001     0.0003  0.0003   0.99
# 0      195    0.00     0.001     0.0003  0.0003   0.99
# 0      196    0.00     0.001     0.0003  0.0003   0.99
# 0      197    0.00     0.001     0.0003  0.0003   0.99
# 0      198   -0.01     0.001     0.0003  0.0003   0.99
# 0      199    0.00     0.001     0.0003  0.0003   0.99
# 0      200   -0.01     0.001     0.0003  0.0003   0.99
#
# [200 rows x 6 columns]

# %%
print(models_to_process[0])
print(models_to_process[11])
# Out:
# retire_agent-6_episode_200.pth
# retire_agent-6_episode_1000.pth

# %%
def combine_histories(first, second):
    if first is None:
        return second
    else:
        split = first['episode'].max()
        return pandas.concat([first, second[second['episode'] > split]])

# %%
a6part1 = load_history(models_to_process[0])
a6part2 = load_history(models_to_process[11])

# %%
combined = combine_histories(a6part1, a6part2)

# %%
print(combined[combined['episode'] < 10])
print(combined[(combined['episode'] > 190) & (combined['episode'] < 210)])
print(combined[combined['episode'] > 990])
# Out:
#   episode  return  actor_lr  critic_lr     tau  gamma
# 0       1    0.00     0.001     0.0003  0.0003   0.99
# 0       2    0.00     0.001     0.0003  0.0003   0.99
# 0       3    0.00     0.001     0.0003  0.0003   0.99
# 0       4   -0.01     0.001     0.0003  0.0003   0.99
# 0       5    0.00     0.001     0.0003  0.0003   0.99
# 0       6   -0.01     0.001     0.0003  0.0003   0.99
# 0       7   -0.01     0.001     0.0003  0.0003   0.99
# 0       8    0.00     0.001     0.0003  0.0003   0.99
# 0       9   -0.01     0.001     0.0003  0.0003   0.99
#   episode  return  actor_lr  critic_lr     tau  gamma
# 0     191   -0.01     0.001     0.0003  0.0003  0.990
# 0     192    0.00     0.001     0.0003  0.0003  0.990
# 0     193   -0.01     0.001     0.0003  0.0003  0.990
# 0     194   -0.01     0.001     0.0003  0.0003  0.990
# 0     195    0.00     0.001     0.0003  0.0003  0.990
# 0     196    0.00     0.001     0.0003  0.0003  0.990
# 0     197    0.00     0.001     0.0003  0.0003  0.990
# 0     198   -0.01     0.001     0.0003  0.0003  0.990
# 0     199    0.00     0.001     0.0003  0.0003  0.990
# 0     200   -0.01     0.001     0.0003  0.0003  0.990
# 0     201    0.10     0.001     0.0003  0.0001  0.995
# 0     202   -0.01     0.001     0.0003  0.0001  0.995
# 0     203   -0.01     0.001     0.0003  0.0001  0.995
# 0     204    0.00     0.001     0.0003  0.0001  0.995
# 0     205    0.00     0.001     0.0003  0.0001  0.995
# 0     206    0.00     0.001     0.0003  0.0001  0.995
# 0     207   -0.01     0.001     0.0003  0.0001  0.995
# 0     208   -0.01     0.001     0.0003  0.0001  0.995
# 0     209    0.00     0.001     0.0003  0.0001  0.995
#   episode  return  actor_lr  critic_lr     tau  gamma
# 0     991   -0.01     0.001     0.0003  0.0001  0.995
# 0     992   -0.01     0.001     0.0003  0.0001  0.995
# 0     993    0.00     0.001     0.0003  0.0001  0.995
# 0     994   -0.01     0.001     0.0003  0.0001  0.995
# 0     995   -0.01     0.001     0.0003  0.0001  0.995
# 0     996   -0.01     0.001     0.0003  0.0001  0.995
# 0     997   -0.01     0.001     0.0003  0.0001  0.995
# 0     998    0.00     0.001     0.0003  0.0001  0.995
# 0     999   -0.01     0.001     0.0003  0.0001  0.995
# 0    1000   -0.01     0.001     0.0003  0.0001  0.995

# %%
def get_agent(filename):
    pattern = re.compile(r".*?agent-(\d+)")
    return int(pattern.match(filename).group(1))

# %%
population_history = {
    'histories' : [None for i in range(0, population_size)],
    'retirements' : []
}

# %%
for filename in models_to_process:
    agent = get_agent(filename)
    new_history = load_history(filename)
    population_history['histories'][agent] = combine_histories(population_history['histories'][agent], new_history)
    if 'retire' in filename:
        population_history['retirements'].append((agent, get_retire_episode(filename)))

# %%
torch.save(population_history, 'population_history.pt')
